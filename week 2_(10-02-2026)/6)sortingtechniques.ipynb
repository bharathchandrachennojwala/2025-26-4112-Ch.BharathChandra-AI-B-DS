# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathchandrachennojwala/2025-26-4112-Ch.BharathChandra-AI-B-DS/blob/main/week%202_(10-02-2026)/6)sortingtechniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 6)Write the code to implement the following sorting algorithms
#
# a. Bubble sort b. Selection sort c. Insertion sort

# %%
#SELECTION SORT
n = int(input("Enter number of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
print("\nOriginal array:", arr)
for i in range(n - 1):
    min_index = i
    for j in range(i + 1, n):
        if arr[j] < arr[min_index]:
            min_index = j
    arr[i], arr[min_index] = arr[min_index], arr[i]
print("Sorted array:", arr)
# Out:
# Enter number of elements: 3
# Enter element 1: 2
# Enter element 2: 3
# Enter element 3: 1
#
# Original array: [2, 3, 1]
# Sorted array: [1, 2, 3]

# %%
#BUBBLE SORT
n = int(input("Enter number of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
print("\nOriginal array:", arr)
for i in range(n-1):
  for j in range(n-1-i):
    if arr[j] > arr[j+1]:
      arr[j],arr[j+1]=arr[j+1],arr[j]
print("Sorted array:", arr)
# Out:
# Enter number of elements: 3
# Enter element 1: 2
# Enter element 2: 1
# Enter element 3: 3
#
# Original array: [2, 1, 3]
# Sorted array: [1, 2, 3]
