# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathchandrachennojwala/2025-26-4112-Ch.BharathChandra-AI-B-DS/blob/main/Week-9/Lasso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DATE : 28-04-2026
#
# WEEK-9
#
# ### QUESTION 32

# %%
import numpy as np
from sklearn.linear_model import Lasso
X=np.array([[1,5,2],[2,6,4],[4,3,6],[7,6,2]])
Y=np.array([5,10,15,20])
model=Lasso(alpha=0.1)
model.fit(X,Y)
print("Coefficient:",model.coef_)
# Out:
# Coefficient: [2.38401043 0.37573922 0.8398587 ]
