# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathchandrachennojwala/2025-26-4112-Ch.BharathChandra-AI-B-DS/blob/main/week%201_(03-02-2026)/1)basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.	Create an account in github and link the repository with the google

# %% [markdown]
# # PART 1: Create a GitHub Account
# # Go to Github
#
# Click Sign Up
#
# Enter:
#
# Email
#
# Password
#
# Username
#
# Verify email
#
# Done
#
# Now you officially exist on GitHub.
# # PART 2: Create a Repository
# Click your profile icon
#
# Click Your repositories
#
# Click New
#
# Fill:
#
# Repository name (example:Data-science-programs)
#
# Keep it Public
#
#  Add README
#
#
# Click Create repository
#
# #PART 3: Link GitHub with Google Colab
# Now we connect it with Google Colab.
#
# Open Google Colab
#
# Click File and then Save a copy in GitHub
#
# It will ask to Authorize GitHub
#
# Choose:
#
# Your repository
#
# File name
#
# Click OK
#
# Done
#
# Your notebook is now directly saved in GitHub.
