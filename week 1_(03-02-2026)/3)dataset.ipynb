# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathchandrachennojwala/2025-26-4112-Ch.BharathChandra-AI-B-DS/blob/main/week%201_(03-02-2026)/3)dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #3. Write the code to download, save, and transform the dataset from a given URL.

# %%
import pandas as pd
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df=pd.read_csv(url)
df.to_csv("iris_dataset.csv", index=False)
print("Dataset downloaded and saved successfully!")
print(df.head())
df["sepal_area"]=df["sepal_length"]*df["sepal_width"]
df.to_csv("iris_transformed.csv",index=False)
print("Dataset transformed and saved")
# Out:
# Dataset downloaded and saved successfully!
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Dataset transformed and saved
