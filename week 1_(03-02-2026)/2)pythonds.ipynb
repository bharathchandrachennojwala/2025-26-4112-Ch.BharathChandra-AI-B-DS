# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathchandrachennojwala/2025-26-4112-Ch.BharathChandra-AI-B-DS/blob/main/week%201_(03-02-2026)/2)pythonds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2.	Write the code to implement the following data structures
#
# a.	List
# b.	Tuples
# c.	Sets and
# d.	Dictionaries

# %%
a=[1,2,3,4,5]
a.append(6)
a.extend([7,8])
print("New list:",a)
# Out:
# New list: [1, 2, 3, 4, 5, 6, 7, 8]

# %%
t = (5, 2, 9, 1)

print("Length:", len(t))
print("Minimum:", min(t))
print("Maximum:", max(t))
print("Sum:", sum(t))
# Out:
# Length: 4
# Minimum: 1
# Maximum: 9
# Sum: 17

# %%
student = {
    "name": "Alex",
    "age": 20,
    "course": "Python"
}

print("Name:", student["name"])
print("Age:", student["age"])
# Out:
# Name: Alex
# Age: 20

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print("Union:", a | b)
print("Intersection:", a & b)
print("Difference:", a - b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference: {1, 2}
