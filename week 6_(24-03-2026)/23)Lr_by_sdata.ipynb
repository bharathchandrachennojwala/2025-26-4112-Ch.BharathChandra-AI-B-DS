# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathchandrachennojwala/2025-26-4112-Ch.BharathChandra-AI-B-DS/blob/main/week%206_(24-03-2026)/23)Lr_by_sdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
X=np.array([1,2,3,4,5]).reshape(-1,1)
Y=np.array([30000, 35000, 45000, 50000, 60000])
reg=LinearRegression()
reg.fit(X, Y)
predictions=reg.predict(X)
print("Slope:",reg.coef_)
print("Intercept:",reg.intercept_)
plt.scatter(X,Y)
plt.plot(X,predictions)
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Salary vs Experience")
plt.show()
# Out:
# Slope: [7500.]
# Intercept: 21500.000000000007
